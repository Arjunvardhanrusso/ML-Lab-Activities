# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data = {
    'Weight': [79, 69, 73, 95, 82, 55, 69, 71, 64, 69],
    'Height': [1.80, 1.68, 1.82, 1.70, 1.87, 1.55, 1.50, 1.78, 1.67, 1.64],
    'Age':    [35, 39, 25, 60, 27, 18, 89, 42, 16, 52],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female']
}

df = pd.DataFrame(data)

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
X = df[['Height', 'Age', 'Gender']]  # Independent variables

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predicted_weights = model.predict(X)

# %%
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: -24.40965468959817
# Coefficients: [47.37930785  0.29668529  8.92206984]

# %%
plt.figure(figsize=(8,5))
plt.plot(range(len(y)), y, marker='o', label='Actual Weight', color='blue')
plt.plot(range(len(y)), predicted_weights, marker='x', label='Predicted Weight', color='red')
plt.title('Actual vs Predicted Body Weight')
plt.xlabel('Person Index')
plt.ylabel('Weight (kg)')
plt.legend()
plt.grid(True)
plt.show()
